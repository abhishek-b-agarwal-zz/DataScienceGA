# %%
import pandas

# %%
sydney = pandas.Series(index=['Mon','Tue','Wed'], data=[37,38,29])

# %%
melbourne = pandas.Series(index=['Sun','Mon','Tue'], data=[25,42,41])

# %%
sydney - melbourne
# Out:
# Mon   -5.0
# Sun    NaN
# Tue   -3.0
# Wed    NaN
# dtype: float64

# %%
sydney+1
# Out:
# Mon    38
# Tue    39
# Wed    30
# dtype: int64

# %%
import pandas

# %%
city_data = pandas.DataFrame({
    'sydney' : sydney,
    'melbourne' : melbourne
})

# %%
city_data
# Out:
#      melbourne  sydney
# Mon       42.0    37.0
# Sun       25.0     NaN
# Tue       41.0    38.0
# Wed        NaN    29.0

# %%
# !pip install html5lib
# !pip install BeautifulSoup4
# Out:
# ...
#   Running setup.py bdist_wheel for webencodings: started
#   Running setup.py bdist_wheel for webencodings: finished with status 'done'
#   Stored in directory: C:\Users\abhisheagrawal\AppData\Local\pip\Cache\wheels\0a\73\c2\1dcc99951b6aeac495e7695505d1837616ca194938f07d1d7b
# Successfully built webencodings
# ...
#   Retrying (Retry(total=4, connect=None, read=None, redirect=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.python.org', port=443): Read timed out. (read timeout=15)",)': /simple/html5lib/
# ...

# %%
list_of_tables = pandas.read_html('http://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population',
                                  header=0,
                                  index_col=0)

# %%
len(list_of_tables)
# Out:
# 3

# %%
list_of_tables[1]
# Out:
#                        Country (or dependent territory)  Population  \
# Rank
# 1                                         China[Note 2]  1381560000
# 2                                                 India  1312010000
# 3                                 United States[Note 3]   324532000
# 4                                             Indonesia   260581000
# 5                                                Brazil   207100000
# 6                                              Pakistan   196368000
# 7                                               Nigeria   186988000
# 8                                            Bangladesh   161947000
# 9                                        Russia[Note 4]   146838993
# 10                                                Japan   126860000
# 11                                               Mexico   122273000
# 12                                          Philippines   103612000
# 13                                             Ethiopia   101853000
# ...
